# %% [markdown]
# temp2

# %% [markdown]
# philosophy component work

# %% [markdown]
# now enhancing mission-vision into component with bg images

# %% [markdown]
# replace inline mission-vision with <x-mission-vision-section> and add bg images mapping

# %% [markdown]
# patch about.blade: add bg key to missionVision, replace mission section markup with component call, and remove old mission css
